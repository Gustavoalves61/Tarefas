# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavoalves61/Tarefas/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Gustavo Alves Costa
# Lista 6





#1

'''
import pandas as pd

data = {'MATEMÁTICA': [60,58,73,51,54,75,48,72,75,83,62,52], 
        'MÚSICA': [80,62,70,83,62,92,79,88,54,82,64,69]} 
        

df = pd.DataFrame(data,columns=['MATEMÁTICA','MÚSICA'])
corrMatrix = df.corr()
print(corrMatrix)

#correlação desprezivel



#2 Que há uma correlação fraca entre a idade da edição e o número de páginas.




#3

data = {'X': [2,3,4,5,4,6,7,8,8,10],  'Y': [48,50,56,52,43,60,62,58,64,72]}
         

df = pd.DataFrame(data,columns=['X','Y'])
corrMatrix = df.corr()
print(corrMatrix)


#indica uma correlação muito forte







#4

import pandas as pd

renda_brutal = {'A': [12,16,18,20,28,30,40,48,50,54],  'B': [7.2,7.4,7.0,6.5,
                                                6.6,6.7,6.0,5.6,6.0,5.5]}
         

df = pd.DataFrame(renda_brutal,columns=['A','B'])
corrMatrix = df.corr()
print(corrMatrix)


#indica uma correlação muito forte




#5

#conjunto1
import pandas as pd
import numpy as np


conjunto1 = pd.Series([ 10 ,8, 13, 9, 11, 14, 6, 4, 12, 7, 5,
 8.04, 6.95 ,7.58 ,8.81 ,8.33 ,9.96 ,7.24 ,4.26 ,10.84 ,4.82 ,5.68])
 

print(conjunto1.mean(), conjunto1.std())  #media e desvio padrão do "conjunto1"


#coeficiente de correlação


import pandas as pd

conjunto1 = {'X': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 
      'Y': [8.04, 6.95 ,7.58 ,8.81 ,8.33 ,9.96 ,7.24 ,4.26 ,10.84 ,4.82 ,5.68]}
         

df = pd.DataFrame(conjunto1,columns=['X','Y'])
corrMatrix = df.corr()
print(corrMatrix)




#conjunto2
import pandas as pd
import numpy as np


conjunto2 = pd.Series([ 10 ,8, 13, 9, 11, 14, 6, 4, 12, 7, 5,
            9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74])
 
 

print(conjunto2.mean(), conjunto2.std())  #media e desvio padrão do "conjunto2"


#coeficiente de correlação

import pandas as pd

conjunto2 = {'X': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 
      'Y': [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]}
         

df = pd.DataFrame(conjunto2,columns=['X','Y'])
corrMatrix = df.corr()
print(corrMatrix)




#conjunto3
import pandas as pd
import numpy as np


conjunto3 = pd.Series([ 10 ,8, 13, 9, 11, 14, 6, 4, 12, 7, 5,
            7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73])
 
 

print(conjunto3.mean(), conjunto3.std())  #media e desvio padrão do "conjunto3"


#coeficiente de correlação

import pandas as pd

conjunto3 = {'X': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 
      'Y': [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]}
         

df = pd.DataFrame(conjunto3,columns=['X','Y'])
corrMatrix = df.corr()
print(corrMatrix)





#conjunto4
import pandas as pd
import numpy as np


conjunto4 = pd.Series([ 8 ,8, 8, 8, 8, 8, 8, 19, 8, 8, 8,
            6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89])
 
 

print(conjunto4.mean(), conjunto4.std())  #media e desvio padrão do "conjunto4"


#coeficiente de correlação

import pandas as pd

conjunto4 = {'X': [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8], 
      'Y': [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]}
         

df = pd.DataFrame(conjunto4,columns=['X','Y'])
corrMatrix = df.corr()
print(corrMatrix)







#6

import pandas as pd

lista = {'produtividade': [100,102,105,108,112,120], 'alimentação': [4,5,1,3,6,2], 
        'exercicios': [1,3,2,4,5,6], 'rodizio': [3,1,2,6,4,5]}
         

df = pd.DataFrame(lista,columns=['produtividade','alimentação','exercicios',
                                 'rodizio'])  
corr = df.corr()
print(corr)




import pandas as pd

programas = { 'Alimentação': [4,5,1,3,6,2], 'Exercicios': [1,3,2,4,5,6], 
             'Rodizio': [3,1,2,6,4,5]}
         

df = pd.DataFrame(programas,columns=['Alimentação','Exercicios','Rodizio'])  
corrMatrix = df.corr()
print(corrMatrix)



#sim,indica uma correlação desprezivel.
