# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavoalves61/Tarefas/blob/main/lista4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Gustavo Alves Costa
# Lista 4




1)
'''
lados = int (input("digite a quantidade de lados:  "))
lado = float(input("digite a medida do lado:  "))

if lados == 3:
  area = lado ** 2 * 3 ** (1/2) / 4
  print("a figura é um triangulo.")
  print("a area é: % .2fcm²" %area)
elif lados == 4:
  area = lado ** 2
  print("a figura é um quadrado.")
  print("a area é: % 2.fcm²" %area)
elif lados == 5:
  print("a figura é um pentagono.")
elif lados < 3 :
  print("a figura é um poligono.")'''




2)
'''
lados = int (input("digite a quantidade de lados:  "))
lado = float(input("digite a medida do lado:  "))

if lados == 3:
  area = lado ** 2 * 3 ** (1/2) / 4
  print("a figura é um triangulo.")
  print("a area é: % .2fcm²" %area)
elif lados == 4:
  area = lado ** 2
  print("a figura é um quadrado.")
  print("a area é: % 2.fcm²" %area)
elif lados == 5:
  print("a figura é um pentagono.")
elif lados < 3:
  print("a figura não é um poligono.")
elif lados > 5:
  print("poligono não identificado.")'''




3)


'''
num1 = int (input("Digite o primeiro número:  "))
num2 = int (input("Digite o segundo número:  "))
num3 = int (input("Digite o terceiro número:  "))

if num1 > num2 and num1 > num3 and num1 :

 print ("o primeiro número digitado é o maior: ", num1)
elif num2 > num1 and num3:
 print ("o segundo número digitado é o maior: ", num2)
elif num3 > num1 and num2:
  print ("o terceiro número digitado é o maior: ", num3)'''







4)
'''
a= float (input("medida do lado 1 do triangulo:  "))
b= float (input("medida do lado 2 do triangulo:  "))
c= float (input("medida do lado 3 do triangulo:  "))



if a<=0 or b<=0 or c<=0 :
  print("lados nulos não são aceitos.")
  quit()

if a>b+c  or b>c+a or c>a+b : 
  print("triangulo escaleno.")
  

if a==b and b==c :
  print("triangulo equilatero.")
  

elif a==b or b==c or c==a :
  print("triangulo isosceles.")'''





5)

'''
a= float (input("digite o primeiro ângulo:  "))
b= float (input("digite o segundo ângulo:  "))
c= float (input("digite o terceiro ângulo:  "))

if a == 90 or b == 90 or c == 90 :
    print("é um triangulo retângulo!.")
elif a < 90 and b < 90 and c < 90:
    print("é um triangulo acutângulo!.")
else:
    print("é um triangulo obtusângulo!.")'''
  




6) 

'''
numero1 = int (input("Digite um número: " ))
for inteiro in range(numero1) :
 print(inteiro)'''
