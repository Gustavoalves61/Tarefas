# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavoalves61/Tarefas/blob/main/lista5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1

'''
import statistics

list = [10, 13, 17, 9, 8, 11, 13, 7]
média = statistics.mean(list)
print("A média aritmética é:", média)

harmonica = statistics.harmonic_mean(list)
print("A média harmonica é:", harmonica)

from scipy.stats.mstats import gmean
geometrica = gmean(list)
print("A média geometrica é:", geometrica)

moda = statistics.mode(list)
print("A moda é:", moda)

variância = statistics.pvariance(list)
print("A variância é:", variância)

desvio_padrão = statistics.stdev(list)
print("O desvio padrão é:", desvio_padrão)



#2

import statistics

list = [67, 75, 63, 72, 77, 78, 81, 77, 80]
média = statistics.mean(list)
print("A média aritmética é:", média)

harmonica = statistics.harmonic_mean(list)
print("A média harmonica é:", harmonica)

from scipy.stats.mstats import gmean
geometrica = gmean(list)
print("A média geometrica é:", geometrica)

moda = statistics.mode(list)
print("A moda é:", moda)

variância = statistics.pvariance(list)
print("A variância é:", variância)

desvio_padrão = statistics.stdev(list)
print("O desvio padrão é:", desvio_padrão)




#3

import statistics

list = [4.0, 4.5, 5.0, 5.0, 5.5, 6.0, 6.0, 6.5, 6.5, 6.5, 6.5, 
      7.0, 7.0, 7.0, 7.0, 7.0, 7.0, 7.5, 8.5, 9.0, 9.0, 9.0, 9.5, 10.0, 
      10.0, 10.5, 11.0, 12.0, 12.5, 13.0, 13.0]
média = statistics.mean(list)
print("A média aritmética é:", média)

desvio_padrão = statistics.stdev(list)
print("O desvio padrão é:", desvio_padrão)

#coeficiente_variação = desvio_padrão / media_dos_números 


#coeficiente de variação é: 

print("O coeficiente de variação é:" ,(2.52/8.01)*100)




#4

import statistics

list = [12, 15, 18, 22, 17, 14, 18, 23, 29, 12]
média = statistics.mean(list)
print("A média aritmética é:", média)

mediana = statistics.median(list)
print("A mediana é:", mediana)

desvio_padrão = statistics.stdev(list)
print("O desvio padrão é:", desvio_padrão)







#6

nota1 = float(input("Nota 1: "))
peso3 = float(input("Peso 3: "))
 
nota2 = float(input("Nota 2: "))
peso4 = float(input("Peso 4: "))

nota3 = float(input("nota 3: "))
peso3 = float(input ("Peso 3: "))
 
# calcula média
media = (nota1*peso3 + nota2*peso4 + nota3*peso3) / (peso3+peso4+peso3)
 
# imprime a média
print(media)
